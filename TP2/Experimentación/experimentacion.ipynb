# %% [markdown]
# # Experimentación Ejercicio 3 TP2 - Kruskal DSU

# %% [markdown]
# ### Implementación de Kruskal con Union by Rank y Path Compression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Leer el archivo CSV
df = pd.read_csv("resultados_ubr_pc.csv")

# Eliminar el espacio adicional en el nombre del encabezado
df.columns = df.columns.str.strip()

# Obtener los valores del tamaño del input y el tiempo
input_size = df["Tamaño del input"]
time = df["Tiempo (ms)"]

# Crear el gráfico
sns.scatterplot(x=time, y=input_size)
plt.xlabel("Tiempo (ms)")
plt.ylabel("Tamaño del input")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Implementación de Kruskal con Union by Size y Path Compression

# %%
# Leer el archivo CSV
df = pd.read_csv("resultados_ubs_pc.csv")

# Eliminar el espacio adicional en el nombre del encabezado
df.columns = df.columns.str.strip()

# Obtener los valores del tamaño del input y el tiempo
input_size = df["Tamaño del input"]
time = df["Tiempo (ms)"]

# Crear el gráfico
sns.scatterplot(x=time, y=input_size)
plt.xlabel("Tiempo (ms)")
plt.ylabel("Tamaño del input")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Comparativa Union by Rank / Union by Size

# %%
# Leer los datos de los dos archivos CSV
df1 = pd.read_csv("resultados_ubr_pc.csv")
df2 = pd.read_csv("resultados_ubs_pc.csv")

# Eliminar el espacio adicional en el nombre del encabezado
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()

# Calcular la diferencia de tiempo
diferencia_tiempo = df2["Tiempo (ms)"] - df1["Tiempo (ms)"]

# Calcular el porcentaje de tiempo adicional
porcentaje_adicional = (diferencia_tiempo / df1["Tiempo (ms)"]) * 100

# Calcular el promedio del porcentaje de tiempo adicional
porcentaje_promedio = porcentaje_adicional.mean()

# Imprimir el porcentaje promedio de tiempo adicional
print("Porcentaje promedio de tiempo adicional:", porcentaje_promedio)
# Out:
# Porcentaje promedio de tiempo adicional: 4.927161489212879

# %% [markdown]
# ### Implementación de Kruskal sin optimizaciones

# %%
# Leer el archivo CSV
df = pd.read_csv("resultados_sin_opt.csv")

# Eliminar el espacio adicional en el nombre del encabezado
df.columns = df.columns.str.strip()

# Obtener los valores del tamaño del input y el tiempo
input_size = df["Tamaño del input"]
time = df["Tiempo (ms)"]

# Crear el gráfico
sns.scatterplot(x=time, y=input_size)
plt.xlabel("Tiempo (ms)")
plt.ylabel("Tamaño del input")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Comparativa UBS-PC vs sin optimizaciones

# %%
# Leer los datos de los dos archivos CSV
df1 = pd.read_csv("resultados_ubr_pc.csv")
df2 = pd.read_csv("resultados_sin_opt.csv")

# Eliminar el espacio adicional en el nombre del encabezado
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()

# Calcular la diferencia de tiempo
diferencia_tiempo = df2["Tiempo (ms)"] - df1["Tiempo (ms)"]

# Calcular el porcentaje de tiempo adicional
porcentaje_adicional = (diferencia_tiempo / df1["Tiempo (ms)"]) * 100

# Calcular el promedio del porcentaje de tiempo adicional
porcentaje_promedio = porcentaje_adicional.mean()

# Imprimir el porcentaje promedio de tiempo adicional
print("Porcentaje promedio de tiempo adicional:", porcentaje_promedio)
# Out:
# Porcentaje promedio de tiempo adicional: 45.402374882551484

# %% [markdown]
# ### Implementación de Kruskal con Union By Rank y sin Path Compression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Leer el archivo CSV
df = pd.read_csv("resultados_ubr_nopc.csv")

# Eliminar el espacio adicional en el nombre del encabezado
df.columns = df.columns.str.strip()

# Obtener los valores del tamaño del input y el tiempo
input_size = df["Tamaño del input"]
time = df["Tiempo (ms)"]

# Crear el gráfico
sns.scatterplot(x=time, y=input_size)
plt.xlabel("Tiempo (ms)")
plt.ylabel("Tamaño del input")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Comparativa UBR-PC vs UBR sin PC

# %%
# Leer los datos de los dos archivos CSV
df1 = pd.read_csv("resultados_ubr_pc.csv")
df2 = pd.read_csv("resultados_ubr_nopc.csv")

# Eliminar el espacio adicional en el nombre del encabezado
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()

# Calcular la diferencia de tiempo
diferencia_tiempo = df2["Tiempo (ms)"] - df1["Tiempo (ms)"]

# Calcular el porcentaje de tiempo adicional
porcentaje_adicional = (diferencia_tiempo / df1["Tiempo (ms)"]) * 100

# Calcular el promedio del porcentaje de tiempo adicional
porcentaje_promedio = porcentaje_adicional.mean()

# Imprimir el porcentaje promedio de tiempo adicional
print("Porcentaje promedio de tiempo adicional:", porcentaje_promedio)
# Out:
# Porcentaje promedio de tiempo adicional: 11.34251090134488

# %% [markdown]
# ### Implementacion de Kruskal para grafos densos

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Leer el archivo CSV
df = pd.read_csv("resultados_densos.csv")

# Eliminar el espacio adicional en el nombre del encabezado
df.columns = df.columns.str.strip()

# Obtener los valores del tamaño del input y el tiempo
input_size = df["Tamaño del input"]
time = df["Tiempo (ms)"]

# Crear el gráfico
sns.scatterplot(x=time, y=input_size)
plt.xlabel("Tiempo (ms)")
plt.ylabel("Tamaño del input")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Comparativa entre Kruskal para grafos densos vs DSU

# %%
# Leer los datos de los dos archivos CSV
df1 = pd.read_csv("resultados_ubr_pc.csv")
df2 = pd.read_csv("resultados_densos.csv")

# Eliminar el espacio adicional en el nombre del encabezado
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()

# Calcular la diferencia de tiempo
diferencia_tiempo = df2["Tiempo (ms)"] - df1["Tiempo (ms)"]

# Calcular el porcentaje de tiempo adicional
porcentaje_adicional = (diferencia_tiempo / df1["Tiempo (ms)"]) * 100

# Calcular el promedio del porcentaje de tiempo adicional
porcentaje_promedio = porcentaje_adicional.mean()

# Imprimir el porcentaje promedio de tiempo adicional
print("Porcentaje promedio de tiempo adicional:", porcentaje_promedio)
# Out:
# Porcentaje promedio de tiempo adicional: -44.0895141889528

# %% [markdown]
# ### Tiempos de ejecución del juez para cada implementación
#
# ![image.png](attachment:image.png)
